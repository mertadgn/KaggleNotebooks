# %% [markdown]
# # Gazi AI Topluluğu ML eğitimi.
# ## Pandas Kullanımı
# ### Gerekli kütüphanelerin içe aktarılması

# %%
import pandas as pd 
import numpy as np
from numpy.random import randn
import warnings
warnings.filterwarnings("ignore")

# %%
#Pandas Series
seri = pd.Series([1,2,3,4,5],[3,4,5,6,7])
seri
# Out:
# 3    1
# 4    2
# 5    3
# 6    4
# 7    5
# dtype: int64

# %%
#Pandas DataFrame Kavramı
#DataFrame oluşturmak
#randn fonksiyonu içine girilen boyutlarda bir matris oluşturur
df = pd.DataFrame(randn(5,6),index = [1,2,3,4,5])
df
# Out:
#           0         1         2         3         4         5
# 1 -1.552638 -0.293143 -0.489717  0.879425 -0.951336  0.297331
# 2  0.144702 -0.438587 -0.474038  0.285363 -1.878454  1.221855
# 3 -0.141358  1.221987  0.048564  0.760912 -0.298616  1.031013
# 4  0.246030 -0.677820  1.116987 -2.444885  0.544143 -0.973170
# 5 -1.436491 -1.920777 -1.120329  1.099620 -0.692933  0.817846

# %%
#Verinin okunması
veri = pd.read_csv("../input/titanicdataset-traincsv/train.csv")
veri
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Bir kolonun veriden çekilmesi
#3 farklı şekilde veriden kolon çekilebilir.
yas = veri.Age
yas2 = veri["Age"]
yas3 = veri[["Age"]]
yas3
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
#Kolonlar üzerinde yapılabilecek işlemler
veri["Age"] = veri["Age"] * veri["Pclass"] 
veri
#Yeni bir kolon ekleyip o kolon içinde işlem yapılabilir
veri["sibsp+parch"] = veri["SibSp"] + veri["Parch"]
#sibsp+parch adında bir kolon oluşturup değerlerini sibsp
#ve parch kolonlarının toplamı olarak yazdırdık.
veri
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   66.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                               Heikkinen, Miss. Laina  female   78.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                             Allen, Mr. William Henry    male  105.0      0
# ...

# %%
#Veriden bir parçanın .loc (Location) yöntemiyle çekilmesi
part1 = veri.loc[[1,3,6,789,345],["Name","Age","Fare"]]
part1
#ilk köşeli parantez hangi indexlerden , ikinci köşeli parantez ise hangi kolonlardan alınacağını belirtir
# Out:
#                                                   Name   Age     Fare
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  53.1000
# 6                              McCarthy, Mr. Timothy J  54.0  51.8625
# 789                           Guggenheim, Mr. Benjamin  46.0  79.2000
# 345                      Brown, Miss. Amelia "Mildred"  48.0  13.0000

# %%
#Veriden bir parçanın .iloc (Index location) yöntemiyle çekilmesi
part2 = veri.iloc[7:38,7:]
part2
#Virgülden öncesi satırların index aralığını sonrası ise kolonların index aralığını belirtir.
# Out:
#     Parch      Ticket      Fare        Cabin Embarked  sibsp+parch
# 7       1      349909   21.0750          NaN        S            4
# 8       2      347742   11.1333          NaN        S            2
# 9       0      237736   30.0708          NaN        C            1
# 10      1     PP 9549   16.7000           G6        S            2
# 11      0      113783   26.5500         C103        S            0
# 12      0   A/5. 2151    8.0500          NaN        S            0
# 13      5      347082   31.2750          NaN        S            6
# 14      0      350406    7.8542          NaN        S            0
# 15      0      248706   16.0000          NaN        S            0
# 16      1      382652   29.1250          NaN        Q            5
# 17      0      244373   13.0000          NaN        S            0
# 18      0      345763   18.0000          NaN        S            1
# 19      0        2649    7.2250          NaN        C            0
# ...

# %%
#Verinin kolonlarını görmek ve değiştirmek
veri.columns = ['Yolcu Numarası', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'sibsp+parch']
veri
#Kolonları yazdırmak için veri.columns yazmanız yeterlidir
# Out:
#      Yolcu Numarası  Survived  Pclass  \
# 0                 1         0       3
# 1                 2         1       1
# 2                 3         1       3
# 3                 4         1       1
# 4                 5         0       3
# ..              ...       ...     ...
# 886             887         0       2
# 887             888         1       1
# 888             889         0       3
# 889             890         1       1
# 890             891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   66.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                               Heikkinen, Miss. Laina  female   78.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                             Allen, Mr. William Henry    male  105.0      0
# ...

# %%
#Verinin boyut bilgisi , size
veri.shape

#verideki hücre sayısıni görmek için 
veri.size
# Out:
# 11583

# %%
#Veri Hakkında Bilgi (.info)
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Yolcu Numarası  891 non-null    int64
#  1   Survived        891 non-null    int64
#  2   Pclass          891 non-null    int64
#  3   Name            891 non-null    object
#  4   Sex             891 non-null    object
#  5   Age             714 non-null    float64
#  6   SibSp           891 non-null    int64
#  7   Parch           891 non-null    int64
#  8   Ticket          891 non-null    object
#  9   Fare            891 non-null    float64
#  10  Cabin           204 non-null    object
#  11  Embarked        889 non-null    object
#  12  sibsp+parch     891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
#Veri tiplerini görme
veri.dtypes
# Out:
# Yolcu Numarası      int64
# Survived            int64
# Pclass              int64
# Name               object
# Sex                object
# Age               float64
# SibSp               int64
# Parch               int64
# Ticket             object
# Fare              float64
# Cabin              object
# Embarked           object
# sibsp+parch         int64
# dtype: object

# %%
#Baştan satır görme
veri.head(9)
#default olarak 5 satır gösterir
# Out:
#    Yolcu Numarası  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# 5               6         0       3
# 6               7         0       1
# 7               8         0       3
# 8               9         1       3
#
#                                                 Name     Sex    Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   66.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                             Heikkinen, Miss. Laina  female   78.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                           Allen, Mr. William Henry    male  105.0      0
# 5                                   Moran, Mr. James    male    NaN      0
# ...

# %%
#Sondan satır görme
veri.tail(12)
#default olarak 5 satır gösterir
# Out:
#      Yolcu Numarası  Survived  Pclass  \
# 879             880         1       1
# 880             881         1       2
# 881             882         0       3
# 882             883         0       3
# 883             884         0       2
# 884             885         0       3
# 885             886         0       3
# 886             887         0       2
# 887             888         1       1
# 888             889         0       3
# 889             890         1       1
# 890             891         0       3
#
#                                               Name     Sex    Age  SibSp  \
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56.0      0
# 880   Shelley, Mrs. William (Imanita Parrish Hall)  female   50.0      0
# 881                             Markun, Mr. Johann    male   99.0      0
# 882                   Dahlberg, Miss. Gerda Ulrika  female   66.0      0
# 883                  Banfield, Mr. Frederick James    male   56.0      0
# ...

# %%
#Veri içerisinden karışık örnekler görme
veri.sample(4)
#default olarak 1 satır gösterir
# Out:
#      Yolcu Numarası  Survived  Pclass                           Name     Sex  \
# 243             244         0       3  Maenpaa, Mr. Matti Alexanteri    male
# 222             223         0       3        Green, Mr. George Henry    male
# 66               67         1       2   Nye, Mrs. (Elizabeth Ramell)  female
# 428             429         0       3               Flynn, Mr. James    male
#
#        Age  SibSp  Parch             Ticket    Fare Cabin Embarked  \
# 243   66.0      0      0  STON/O 2. 3101275   7.125   NaN        S
# 222  153.0      0      0              21440   8.050   NaN        S
# 66    58.0      0      0         C.A. 29395  10.500   F33        S
# 428    NaN      0      0             364851   7.750   NaN        Q
#
#      sibsp+parch
# 243            0
# 222            0
# 66             0
# 428            0

# %%
#Bir kolon içerisindeki benzersiz değerleri görmek
veri.Pclass.unique()
# Out:
# array([3, 1, 2])

# %%
#Kolon içindeki benzersiz değerlerin sayısını görmek
veri.Pclass.value_counts()
veri.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#Bir kolonu kopyalamak
pclasscopy = veri[["Pclass"]].copy()
pclasscopy = pd.DataFrame(pclasscopy)
pclasscopy
# Out:
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
#Veri hakkındaki istatiksel verileri almak
veri.describe().T
#.T transpose (devrik) matris işlemini yapar
# Out:
#                 count        mean         std   min       25%       50%  \
# Yolcu Numarası  891.0  446.000000  257.353842  1.00  223.5000  446.0000
# Survived        891.0    0.383838    0.486592  0.00    0.0000    0.0000
# Pclass          891.0    2.308642    0.836071  1.00    2.0000    3.0000
# Age             714.0   61.938151   34.379609  0.92   38.0000   58.0000
# SibSp           891.0    0.523008    1.102743  0.00    0.0000    0.0000
# Parch           891.0    0.381594    0.806057  0.00    0.0000    0.0000
# Fare            891.0   32.204208   49.693429  0.00    7.9104   14.4542
# sibsp+parch     891.0    0.904602    1.613459  0.00    0.0000    0.0000
#
#                   75%       max
# Yolcu Numarası  668.5  891.0000
# Survived          1.0    1.0000
# Pclass            3.0    3.0000
# Age              81.0  222.0000
# SibSp             1.0    8.0000
# Parch             0.0    6.0000
# Fare             31.0  512.3292
# sibsp+parch       1.0   10.0000

# %%
#Korelasyon Matrisi oluşturma
veri.corr()
# Out:
#                 Yolcu Numarası  Survived    Pclass       Age     SibSp  \
# Yolcu Numarası        1.000000 -0.005007 -0.035144  0.010519 -0.057527
# Survived             -0.005007  1.000000 -0.338481 -0.338900 -0.035322
# Pclass               -0.035144 -0.338481  1.000000  0.447533  0.083081
# Age                   0.010519 -0.338900  0.447533  1.000000 -0.301426
# SibSp                -0.057527 -0.035322  0.083081 -0.301426  1.000000
# Parch                -0.001652  0.081629  0.018443 -0.146537  0.414838
# Fare                  0.012658  0.257307 -0.549500 -0.330121  0.159651
# sibsp+parch          -0.040143  0.016639  0.065997 -0.273152  0.890712
#
#                    Parch      Fare  sibsp+parch
# Yolcu Numarası -0.001652  0.012658    -0.040143
# Survived        0.081629  0.257307     0.016639
# Pclass          0.018443 -0.549500     0.065997
# Age            -0.146537 -0.330121    -0.273152
# SibSp           0.414838  0.159651     0.890712
# ...

# %%
#Eksik verilerin gösterimi
veri.isnull().sum()
# Out:
# Yolcu Numarası      0
# Survived            0
# Pclass              0
# Name                0
# Sex                 0
# Age               177
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Cabin             687
# Embarked            2
# sibsp+parch         0
# dtype: int64

# %%
#Eksik verilerin doldurulması
#->YORUM SATIRINI KALDIRMAK İÇİN TIRNAKLARI KALDIRIN :)
"""
veri["Age"] = veri["Age"].fillna(veri["Age"].median())
veri.isnull().sum()
#Sayısal değerlerde boş verileri doldurmak için medyan veya ortalama değerleri kullanılabilir

veri["Embarked"] = veri["Embarked"].fillna(veri["Embarked"].mode()[0])
veri.isnull().sum()
#Kategorik değerlerde boş verileri doldurmak için mod değeri kullanılabilir
"""
# Out:
# '\nveri["Age"] = veri["Age"].fillna(veri["Age"].median())\nveri.isnull().sum()\n#Sayısal değerlerde boş verileri doldurmak için medyan veya ortalama değerleri kullanılabilir\n\nveri["Embarked"] = veri["Embarked"].fillna(veri["Embarked"].mode()[0])\nveri.isnull().sum()\n#Kategorik değerlerde boş verileri doldurmak için mod değeri kullanılabilir\n'

# %%
#Eksik verilerin veriden atılması (axis , thresh)
"""
veri.isnull().sum()
veri.dropna(axis=0,thresh = 12)
#Dropna fonksiyonu boş gördüğü satırı YA DA sütünü veriden atar
#axis, satır mı yoksa sütun mu olacağını belirtir.
#thresh = n olarak belirtilirse anlamı : en az n adet boş olmayan değer varsa veriyi silme.
"""
# Out:
# '\nveri.isnull().sum()\nveri.dropna(axis=0,thresh = 12)\n#Dropna fonksiyonu boş gördüğü satırı YA DA sütünü veriden atar\n#axis, satır mı yoksa sütun mu olacağını belirtir.\n#thresh = n olarak belirtilirse anlamı : en az n adet boş olmayan değer varsa veriyi silme.\n'

# %%
#Gruplama fonksiyonu (groupby)
veri.groupby("Age").sum()
# Out:
#         Yolcu Numarası  Survived  Pclass  SibSp  Parch      Fare  sibsp+parch
# Age
# 0.92               306         1       1      1      2  151.5500            3
# 1.26               804         1       3      0      1    8.5167            1
# 1.34               756         1       2      1      1   14.5000            2
# 1.66               911         2       4      1      3   47.7500            4
# 2.00              1310         2       5      3      5  227.5542            8
# ...                ...       ...     ...    ...    ...       ...          ...
# 183.00             327         0       3      0      0    6.2375            0
# 189.00             484         1       3      0      0    9.5875            0
# 195.00             281         0       3      0      0    7.7500            0
# 211.50             117         0       3      0      0    7.7500            0
# 222.00             852         0       3      0      0    7.7750            0
#
# [128 rows x 7 columns]

# %%
#İki veri setinde birleştirme (concat)
yas = veri[["Age"]]
fare = veri[["Fare"]]
concat = pd.concat([yas,fare],axis=1)
concat
# Out:
#        Age     Fare
# 0     66.0   7.2500
# 1     38.0  71.2833
# 2     78.0   7.9250
# 3     35.0  53.1000
# 4    105.0   8.0500
# ..     ...      ...
# 886   54.0  13.0000
# 887   19.0  30.0000
# 888    NaN  23.4500
# 889   26.0  30.0000
# 890   96.0   7.7500
#
# [891 rows x 2 columns]

# %%
#Veri üzerinde fonksiyon atama (apply)
def kare(x):
    return x*x
veri[["Age"]] = veri[["Age"]].apply(kare)

# %%
#Verileri değerlere ve indexlere göre sıralama
veri.sort_index()
#Veriler indexine göre sıralanır
veri.sort_values(by = "Fare")
#veriler fare değerine göre sıralanır
# Out:
#      Yolcu Numarası  Survived  Pclass                                Name  \
# 271             272         1       3        Tornquist, Mr. William Henry
# 597             598         0       3                 Johnson, Mr. Alfred
# 302             303         0       3     Johnson, Mr. William Cahoone Jr
# 633             634         0       1       Parr, Mr. William Henry Marsh
# 277             278         0       2         Parkes, Mr. Francis "Frank"
# ..              ...       ...     ...                                 ...
# 438             439         0       1                   Fortune, Mr. Mark
# 341             342         1       1      Fortune, Miss. Alice Elizabeth
# 737             738         1       1              Lesurer, Mr. Gustave J
# 258             259         1       1                    Ward, Miss. Anna
# 679             680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex      Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# ...

# %%
#Veriden bir veya birkaç kolonu çıkarmak
veri.drop(["Name","Cabin","Ticket","Yolcu Numarası"],axis=1,inplace=True)
veri
# Out:
#      Survived  Pclass     Sex      Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    male   4356.0      1      0   7.2500        S
# 1           1       1  female   1444.0      1      0  71.2833        C
# 2           1       3  female   6084.0      0      0   7.9250        S
# 3           1       1  female   1225.0      1      0  53.1000        S
# 4           0       3    male  11025.0      0      0   8.0500        S
# ..        ...     ...     ...      ...    ...    ...      ...      ...
# 886         0       2    male   2916.0      0      0  13.0000        S
# 887         1       1  female    361.0      0      0  30.0000        S
# 888         0       3  female      NaN      1      2  23.4500        S
# 889         1       1    male    676.0      0      0  30.0000        C
# 890         0       3    male   9216.0      0      0   7.7500        Q
#
#      sibsp+parch
# 0              1
# 1              1
# 2              0
# 3              1
# 4              0
# ...
